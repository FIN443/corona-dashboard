# %%
import plotly.express as px
from data import countries_df

df = countries_df

for value in df.values:
    for value_column in value:
        if type(value_column) is not str:
            print(type(value_column))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# ...
